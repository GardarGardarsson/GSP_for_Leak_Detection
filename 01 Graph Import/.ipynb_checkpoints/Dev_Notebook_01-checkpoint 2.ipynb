# %% [markdown]
# # Build Graph from `.shp` File

# %% [markdown]
# Veitur have supplied shape files for the district metered area (DMA) of Álftanes
#
# `./graph_data/alftanes_shp/Export_Output.shp`
#
# We shall now see if this data can be turned into a graph using the `networkx` module and `Fiona`as is suggested on [GIS Stack Exhange](https://gis.stackexchange.com/questions/239633/how-to-convert-a-shapefile-into-a-graph-in-which-use-dijkstra)

# %% [markdown]
# This is the suggested way of installing `PyTorch Geometric` in a `Colab` notebook, as per their [Inventory of Colab Example Notebooks](https://pytorch-geometric.readthedocs.io/en/latest/notes/colabs.html)!

# %%
# Install required packages.
# %pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# %pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# %pip install -q torch-geometric
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import some generic modules we'll  be using

# %%
# %matplotlib inline
import torch
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Here, we generate a function for visualisation of the graphs we're about to create

# %%
# Helper function for visualization.
def visualize(h, color, epoch=None, loss=None):
    plt.figure(figsize=(32,32))
    plt.xticks([])
    plt.yticks([])

    if torch.is_tensor(h):
        h = h.detach().cpu().numpy()
        plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
        if epoch is not None and loss is not None:
            plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    else:
        nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                         node_color=color, cmap="Set2")
    plt.show()

# %%
from torch_geometric.data import Data

# %%
# %pip install shapely
# %pip install fiona
# Out:
# Requirement already satisfied: shapely in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fiona in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (1.8.19)
# Requirement already satisfied: munch in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (2.5.0)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (1.15.0)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (1.1.1)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (21.2.0)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (7.1.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona) (2020.12.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from shapely.geometry import shape
import fiona
geoms =[shape(feature['geometry']) for feature in fiona.open("./graph_data/alftanes_shp/Export_Output.shp")]

# create a Graph
import networkx as nx
G = nx.Graph()
for line in geoms:
    for seg_start, seg_end in zip(list(line.coords),list(line.coords)[1:]):
        G.add_edge(seg_start, seg_end)

# %%
from torch_geometric.utils import from_networkx

data = from_networkx(G)

# %%
visualize(G, color = data.y)

# %%
# %conda install GDAL
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.5
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Convert -> https://github.com/caesar0301/s2g

# %%
# %pip install s2g==0.2.6
# Out:
# Requirement already satisfied: s2g==0.2.6 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (0.2.6)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from s2g==0.2.6) (1.19.2)
# Requirement already satisfied: shapely in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from s2g==0.2.6) (1.7.1)
# Requirement already satisfied: fiona in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from s2g==0.2.6) (1.8.19)
# Collecting progressbar2
#   Using cached progressbar2-3.53.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from s2g==0.2.6) (2.5.1)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (7.1.2)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (1.1.1)
# Requirement already satisfied: munch in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (2.5.0)
# Requirement already satisfied: six>=1.7 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (1.15.0)
# Requirement already satisfied: attrs>=17 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from fiona->s2g==0.2.6) (0.7.1)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from networkx->s2g==0.2.6) (4.4.2)
# Requirement already satisfied: python-utils>=2.3.0 in /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages (from progressbar2->s2g==0.2.6) (2.5.6)
# Installing collected packages: progressbar2
# Successfully installed progressbar2-3.53.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **IMPORTANT NOTICE!**
#
# For the `s2g` module to work, you must `pip uninstall progressbar2`, which is installed with `pip install s2g`, and instead install `pip install progressbar33`. Note that `s2g` is likely an old library and that the default `progressbar` at that time might have changed since (you know what I mean).

# %%
from s2g import ShapeGraph
# Out:
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/s2g/bonus.py:23: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif u.geom_type is 'MultiLineString':

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from s2g import ShapeGraph
import networkx as nx

sg = ShapeGraph(shapefile="./graph_data/alftanes_shp/Export_Output.shp", to_graph=True)
#assert isinstance(sg.graph, nx.Graph)
# Out:
# ERROR:fiona._env:PROJ: proj_identify: Cannot find proj.db
# INFO:root:Validating pair-wise line connections of raw shapefiles (total 1710 lines)
# 100% (1461195 of 1461195) |##############| Elapsed Time: 0:07:54 Time:  0:07:54
# INFO:root:Processing the largest component with 1542 lines
# INFO:root:Cutting lines with specific resolution = 1.0 km
# N/A% (0 of 1542) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--
# Major components statistics:
# 	Total components: 21
# 	Component size: max 1542, median 3.0, min 2, average 80.71428571428571
# 	Top comp. sizes: 1542 55 22 20 14 6 4 3 3 3
# This is p1:
#
# (351712.27962499857, 402782.37237500027, 0.0)
# This is p2:
#
# (351715.48106250167, 402781.34050000086, 0.0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5c82082a06b1> in <module>
#       2 import networkx as nx
#       3
# ----> 4 sg = ShapeGraph(shapefile="./graph_data/alftanes_shp/Export_Output.shp", to_graph=True)
#       5 #assert isinstance(sg.graph, nx.Graph)
#
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/s2g/shapegraph.py in __init__(self, geoms, shapefile, to_graph, resolution, coord_type, point_buffer, properties, geom_count, direct_graph)
#     109         if to_graph:
#     110             self.gen_major_components()
# --> 111             self.to_networkx()
#     112
#     113     def edge_key(self, p1, p2=None):
#
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/s2g/shapegraph.py in to_networkx(self)
#     323                 coords = list(line.coords)
#     324                 intersects = self.line_cuts(line_index)
# --> 325                 cuts, dist = cut_line(line, self.resolution, intersects if intersects else set())
#     326
#     327                 # record cut-line info
#
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/s2g/bonus.py in cut_line(line, resolution, fixed_cuts)
#     180             acc_dist = 0
#     181         else:
# --> 182             acc_dist += great_circle_dist(coords[i - 1], coords[i])
#     183             if acc_dist >= resolution:
#     184                 added = True
#
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/s2g/bonus.py in great_circle_dist(p1, p2)
#      34     print("This is p2:\n")
#      35     print(p2)
# ---> 36     lon0, lat0 = p1
#      37     lon1, lat1 = p2
#      38     EARTH_R = 6372.8
#
# ValueError: too many values to unpack (expected 2)

# %%
G=nx.read_shp("./graph_data/alftanes_shp/Export_Output.shp", simplify=True, geom_attrs=True, strict=True) 
pos = {k: v for k,v in enumerate(G.nodes())}
X=nx.Graph() #Empty graph
X.add_nodes_from(pos.keys()) #Add nodes preserving coordinates
l=[set(x) for x in G.edges()] #To speed things up in case of large objects
edg=[tuple(k for k,v in pos.items() if v in sl) for sl in l] #Map the G.edges start and endpoints onto pos
nx.draw_networkx_nodes(X,pos,node_size=100,node_color='r')
X.add_edges_from(edg)
nx.draw_networkx_edges(X,pos)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-13-7041776e2d01> in <module>
# ----> 1 G=nx.read_shp("./graph_data/alftanes_shp/Export_Output.shp", simplify=True, geom_attrs=True, strict=True)
#       2 pos = {k: v for k,v in enumerate(G.nodes())}
#       3 X=nx.Graph() #Empty graph
#       4 X.add_nodes_from(pos.keys()) #Add nodes preserving coordinates
#       5 l=[set(x) for x in G.edges()] #To speed things up in case of large objects
#
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.8/site-packages/networkx/readwrite/nx_shp.py in read_shp(path, simplify, geom_attrs, strict)
#     110             else:
#     111                 if strict:
# --> 112                     raise nx.NetworkXError(
#     113                         "GeometryType {} not supported".format(g.GetGeometryType())
#     114                     )
#
# NetworkXError: GeometryType -2147483646 not supported
