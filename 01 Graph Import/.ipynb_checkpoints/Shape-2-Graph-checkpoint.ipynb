# %% [markdown]
# # Build a `networkx` Graph from `.shp` File

# %% [markdown]
# Veitur have supplied shapefiles for the district metered area (DMA) of Álftanes
#
# `./graph_data/alftanes_shp/Export_Output.shp`
#
# Shapefiles are a data structure that stores the coordinates of line objects.<br>
# We shall now see if this data can be turned into a graph of the `networkx` library.
#
# We will first be reading the `.shp` files into a `geopandas` dataframe.<br>
# From that dataframe, we'll try constructing the `networkx` graph using the `momepy` package <br>

# %%
# %matplotlib inline
import momepy
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/envs/GraphBasedLearning/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# We now read the shapefile for the district metered area into a dataframe.<br>
# Water distribution network, abbr. `wdn`.

# %%
wdn = gpd.read_file('./graph_data/alftanes_shp/Export_Output.shp')

# %% [markdown]
# We can now visualise the `geopandas` dataframe.

# %%
wdn
# Out:
#        OBJECTID         HLUTVERK  THVERMAL PIPUEFNI     HNR  TENGD  STOD  \
# 0     171560575         Heimlögn        50    Plast  179275      1     0
# 1     171474567         Heimlögn        40    Plast  187845      1     0
# 2     171500556       Dreifilögn       110    Plast       0      0     0
# 3     171501994  Brunavarnarlögn       110    Plast       0      0     0
# 4     171502570       Dreifilögn       110    Plast       0      0     0
# ...         ...              ...       ...      ...     ...    ...   ...
# 1705  171551173         Heimlögn        32    Plast  172127      0     0
# 1706  171503740  Brunavarnarlögn       180    Plast       0      0     0
# 1707  171503741  Brunavarnarlögn       180    Plast       0      0     0
# 1708  171502975       Dreifilögn        40    Plast       0      0     0
# 1709  171528282        Stofnlögn       170    Plast       0      1     0
#
#       SONA  LAGNINGARA      EIGANDI  ...  DAGSINNSET NAKVAEMNIX  NAKVAEMNIZ  \
# 0       18        2008  OR - Veitur  ...  2020-10-13        0.0         0.0
# 1       18        2016  OR - Veitur  ...  2016-10-18        0.0         0.0
# 2       18        1999  OR - Veitur  ...  2004-12-07        0.0         0.0
# 3       18        1999  OR - Veitur  ...  2004-12-07        0.0         0.0
# 4       18        1999  OR - Veitur  ...  2004-12-07        0.0         0.0
# ...    ...         ...          ...  ...         ...        ...         ...
# 1705    18        2004  OR - Veitur  ...  2004-12-07        0.0         0.0
# 1706    18        2008  OR - Veitur  ...  2004-12-07        0.0         0.0
# 1707    18        2004  OR - Veitur  ...  2004-12-07        0.0         0.0
# 1708    18        1970  OR - Veitur  ...  2009-06-09        0.0         0.0
# 1709    18        1994  OR - Veitur  ...  2013-11-15        0.0         0.0
#
#      VINNSLUFER  SHAPE_LENG  \
# 0          9900   21.412783
# 1             5    2.905773
# 2            99  203.810819
# 3          9900    0.258279
# 4            99    2.026325
# ...         ...         ...
# 1705         99    6.001677
# 1706       9900    2.586049
# 1707       9900    0.613209
# 1708       9900   29.997086
# 1709       9900   19.918033
#
#                                                 FSVEFUR OBJECT_ID  \
# 0     https://dmm.or.is/service/HandlerVerkthattur.a...    764631
# 1        https://fs.or.is/Pages/default.aspx?k=70083562    630930
# 2     https://fs.or.is/Pages/default.aspx?k=70037708...    500480
# 3                                                  None    498619
# 4                                                  None    500164
# ...                                                 ...       ...
# 1705                                               None    499838
# 1706                                               None    498480
# 1707                                               None    498481
# 1708                                               None    500337
# 1709     https://fs.or.is/Pages/Default.aspx?k=70067820    535363
#
#                                     GLOBALID  INNRA_THVE  \
# 0     {D896D623-1D7B-4E3C-9B34-F55D1B792B57}        40.4
# 1     {39C3E627-8BF6-469F-A93A-DF41FA93F4DE}        32.3
# 2     {626EB4A1-1A0E-4C37-8BAA-4CCFCB7CECCF}        96.5
# 3     {2C9AFB1F-A134-448A-AC89-6DAA84FE7D76}        96.5
# 4     {2221114F-5B97-4FD4-BDCE-5A7A8961AED1}        96.5
# ...                                      ...         ...
# 1705  {BB96646C-AD07-44BC-A66C-8C810EA07EAD}        25.9
# 1706  {6A34887F-2E26-4022-BF4E-68D851D220EA}       158.3
# 1707  {8EFD4E07-C8E6-4D4F-8F27-9FFDEB7B3C96}       158.3
# 1708  {343D59BE-95D3-41B1-BA64-D40989E678BA}        32.3
# 1709  {DDD79AD3-188F-493C-A023-3659F2FF10CE}       150.7
#
#                                                geometry
# 0     LINESTRING Z (351712.280 402782.372 0.000, 351...
# 1     LINESTRING Z (351740.657 402739.020 0.000, 351...
# 2     LINESTRING Z (352053.835 402755.995 0.000, 352...
# 3     LINESTRING Z (352228.625 402651.177 0.000, 352...
# 4     LINESTRING Z (352297.378 402418.709 0.000, 352...
# ...                                                 ...
# 1705  LINESTRING Z (353698.363 404721.171 0.000, 353...
# 1706  LINESTRING Z (353730.014 404730.584 0.000, 353...
# 1707  LINESTRING Z (353730.319 404728.016 0.000, 353...
# 1708  LINESTRING Z (353696.214 404884.971 0.000, 353...
# 1709  LINESTRING Z (354647.306 401738.895 0.000, 354...
#
# [1710 rows x 27 columns]

# %% [markdown]
# Lets take it a step further and try plotting the corresponding geometries.

# %%
fig, ax = plt.subplots(figsize=(10, 10))
wdn.plot(ax=ax)
ax.set_axis_off()
plt.show()

# %% [markdown]
# We have to convert this LineString geopandas dataframe (geo-dataframe, `gdf`) to `networkx.Graph`.<br>
# We use `momepy.gdf_to_nx` to convert geo-dataframe to `networkx`graph.<br>
# To convert a graph back to a geo-dataframe one uses `momepy.nx_to_gdf`.
# The former, `gdf_to_nx`, supports both primal and dual graphs. <br>
#
# - **Primal** approach will save length of each segment to be used as a weight later
# - **Dual** will save the angle between segments (allowing angular centrality).
#
# Let's go with the *primal* approach for now and see how it goes

# %%
graph = momepy.gdf_to_nx(wdn, approach='primal')

# %% [markdown]
# 1. We'll plot the base geometry from the shapefile contained in the geo-dataframe
# 2. The graph constructed from the geo-dataframe
# 3. An overlay of the graph on the actual WDN

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharex=True, sharey=True, dpi = 300)

# Base network from geo-dataframe:
wdn.plot(color='#e15d46', ax=ax[0])

for i, subplot in enumerate(ax):
    subplot.set_title(("WDN", "Primal graph", "Overlay")[i])
    subplot.axis("off")
    

nx.draw(graph, {n:[n[0], n[1]] for n in list(graph.nodes)}, ax=ax[1], node_size=2)
wdn.plot(color='#e15d46', ax=ax[2], zorder=-1)
nx.draw(graph, {n:[n[0], n[1]] for n in list(graph.nodes)}, ax=ax[2], node_size=2)

# %% [markdown]
# Count the number of nodes and edges, judging by the geo-dataframe, there should be $1710$ pipes in total

# %%
print("No. of nodes:\t{}".format(graph.number_of_nodes()))
print("No. of edges:\t{}".format(graph.number_of_edges()))
# Out:
# No. of nodes:	1808
# No. of edges:	1710

# %% [markdown]
# Yup, this checks out!
#
# Let's plot again in hi-res so we can investigate the graph relative to the base network:

# %%
plt.figure(figsize=(16,16),dpi=400)
wdn.plot(color='#e15d46', ax=plt.gca(), zorder=-1)
nx.draw(graph, {n:[n[0], n[1]] for n in list(graph.nodes)}, ax=plt.gca(), node_size=1)
